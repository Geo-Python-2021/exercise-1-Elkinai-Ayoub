# %%
ice_cream_rating = 8
sleeping_rating = 8

# %%
first_name = input("enter your first name")
last_name = input("enter your last name")
my_name = first_name +" "+ last_name
print(my_name)
# Out:
# enter your first name ayoub
# enter your last name elkinani
# ayoub elkinani

# %%
happiness_rating = ice_cream_rating + sleeping_rating
print(happiness_rating)
# Out:
# 16

# %%
a,b,c = ice_cream_rating,first_name,happiness_rating
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Yes, No

# %%
print(f"My name is {first_name} and I give eating ice cream a score of {ice_cream_rating } out of 10!")
print(f"I am {my_name} and my sleeping enjoyment rating is {sleeping_rating}/10!")
print(f"Based on the factors above, my happiness rating is {happiness_rating/2} out of 10, or {happiness_rating/2*10} %!")
# Out:
# My name is ayoub and I give eating ice cream a score of 8 out of 10!
# I am ayoub elkinani and my sleeping enjoyment rating is 8/10!
# Based on the factors above, my happiness rating is 8.0 out of 10, or 80.0 %!
